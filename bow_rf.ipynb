# %%
import json
import pandas as pd
import numpy as np
import wandb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    precision_recall_fscore_support,
    confusion_matrix
)

# %%
data = []
with open("long_queries_data.json", 'r', encoding='utf-8', errors='replace') as f:
    for line in f:
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError as e:
            print(f"Skipping invalid line: {e}")
            
df_queries = pd.DataFrame(data)
df_queries.head()
# Out:
#         name employee_tenure                  department  \
# 0  Alexander     experienced  Customer Support / Service
# 1  Alexander     experienced  Customer Support / Service
# 2  Alexander     experienced  Customer Support / Service
# 3  Alexander     experienced  Customer Support / Service
# 4  Alexander     experienced  Customer Support / Service
#
#                job_title company_size     company_sector  \
# 0  Resolution Specialist    mid-sized  Legal & Law Firms
# 1  Resolution Specialist    mid-sized  Legal & Law Firms
# 2  Resolution Specialist    mid-sized  Legal & Law Firms
# 3  Resolution Specialist    mid-sized  Legal & Law Firms
# 4  Resolution Specialist    mid-sized  Legal & Law Firms
#
#                                                tasks  \
# 0  [Respond to 3 customer complaints via email, I...
# 1  [Respond to 3 customer complaints via email, I...
# 2  [Respond to 3 customer complaints via email, I...
# 3  [Respond to 3 customer complaints via email, I...
# 4  [Respond to 3 customer complaints via email, I...
#
#                                         long_queries  line_idx  task_idx task  \
# 0  resolution support customer service legal issu...         0         0  NaN
# 1  customer complaints email template resolution ...         0         0  NaN
# 2  complaints management service customer support...         0         0  NaN
# 3  legal firm customer service email responses co...         0         0  NaN
# 4  mid-sized law firms complaint handling procedu...         0         0  NaN
#
#    user_idx final_tool
# 0        17      Gmail
# 1        17      Gmail
# 2        17      Gmail
# 3        17      Gmail
# 4        17      Gmail

# %%
config = {
    "model": "RandomForest",
    "vectorizer": "Tfidf",
    "ngram_range": (1, 2),
    "stop_words": "english",
    "max_features": 5000,
    "n_estimators": 100
}

wandb.init(project="pack-intent", name="rf-tfidf-v1", config=config)
# Out:
# wandb: Currently logged in as: kelly-deng (fa-orchestra-brain) to https://wandb.gnlp.io. Use `wandb login --relogin` to force relogin
# Waiting for wandb.init()...
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>/Users/kellydeng/Desktop/query2pack/wandb/run-20250617_113755-gmg2wk7e</code>
# Syncing run <strong><a href='https://wandb.gnlp.io/fa-orchestra-brain/pack-intent/runs/gmg2wk7e' target="_blank">rf-tfidf-v1</a></strong> to <a href='https://wandb.gnlp.io/fa-orchestra-brain/pack-intent' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.gnlp.io/fa-orchestra-brain/pack-intent' target="_blank">https://wandb.gnlp.io/fa-orchestra-brain/pack-intent</a>
#  View run at <a href='https://wandb.gnlp.io/fa-orchestra-brain/pack-intent/runs/gmg2wk7e' target="_blank">https://wandb.gnlp.io/fa-orchestra-brain/pack-intent/runs/gmg2wk7e</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.gnlp.io/fa-orchestra-brain/pack-intent/runs/gmg2wk7e?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_queries["long_queries"],
    df_queries["final_tool"],
    test_size=0.2,
    random_state=42,
    stratify=df_queries["final_tool"]
)

# %%
vectorizer = TfidfVectorizer(
    stop_words=config["stop_words"],
    ngram_range=config["ngram_range"],
    max_features=config["max_features"]
)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
clf = RandomForestClassifier(
    n_estimators=config["n_estimators"],
    class_weight="balanced",
    random_state=42
)
clf.fit(X_train_vec, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred = clf.predict(X_test_vec)
acc = accuracy_score(y_test, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average='weighted'
)

wandb.log({
    "accuracy": acc,
    "precision_weighted": precision,
    "recall_weighted": recall,
    "f1_weighted": f1
})

report = classification_report(y_test, y_pred, output_dict=True)
wandb.log({"classification_report": report})
wandb.sklearn.plot_confusion_matrix(y_test, y_pred, labels=clf.classes_)

wandb.finish()
# Out:
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_weighted</td><td>▁</td></tr><tr><td>precision_weighted</td><td>▁</td></tr><tr><td>recall_weighted</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.50743</td></tr><tr><td>f1_weighted</td><td>0.47681</td></tr><tr><td>precision_weighted</td><td>0.48982</td></tr><tr><td>recall_weighted</td><td>0.50743</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rf-tfidf-v1</strong> at: <a href='https://wandb.gnlp.io/fa-orchestra-brain/pack-intent/runs/gmg2wk7e' target="_blank">https://wandb.gnlp.io/fa-orchestra-brain/pack-intent/runs/gmg2wk7e</a><br> View project at: <a href='https://wandb.gnlp.io/fa-orchestra-brain/pack-intent' target="_blank">https://wandb.gnlp.io/fa-orchestra-brain/pack-intent</a><br>Synced 6 W&B file(s), 1 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250617_113755-gmg2wk7e/logs</code>
