# %%
import json
import pandas as pd
import re
import numpy as np
import os

# %%
annot_validated = pd.read_json("validation_out.json", lines=True)
annot_validated.head()
# Out:
#    user_idx  task_idx                                               task  \
# 0       185         0  Reviewing shipment schedules for the next quarter
# 1       185         1  Conducting cycle count on raw materials inventory
# 2       185         2  Analyzing sales data to identify trends in mat...
# 3       185         3             Creating and updating vendor contracts
# 4       185         4  Verifying compliance with regulatory standards...
#
#   tool_to_search ok better
# 0  Google Sheets  Y      -
# 1  Google Sheets  Y      -
# 2  Google Sheets  Y      -
# 3    Google Docs  Y      -
# 4     Confluence  Y      -

# %%
annot_validated['ok'].value_counts()
# Out:
# ok
# Y    79835
# N    24725
# Name: count, dtype: int64

# %%
print(len(annot_validated))

# Which expected user_idx values are missing?
expected = set(range(annot_validated["user_idx"].min(), annot_validated["user_idx"].max() + 1)) 
present  = set(annot_validated["user_idx"].unique())
missing  = expected - present
print("missing user_idx:", sorted(missing))

# Verify each user_idx has exactly 10 task_idx values
counts = annot_validated.groupby("user_idx")["task_idx"].nunique()
bad    = counts[counts != 10]
print(f"\nusers with wrong task count: {len(bad)}")
display(bad.head())
# Out:
# 104560
# missing user_idx: []
#
# users with wrong task count: 0
# Series([], Name: task_idx, dtype: int64)

# %%
# random sample 50 rows of replaced annotations
for _, row in annot_validated[annot_validated['better'] != "-"].sample(50).iterrows():
    print(row['task'])
    print(row['tool_to_search'])
    print(row['better'])
    print('-' * 80)
# Out:
# Negotiating settlement agreement with disgruntled customer
# Coda
# Confluence
# --------------------------------------------------------------------------------
# Reviewing and updating financial reports
# Confluence
# Google Sheets
# --------------------------------------------------------------------------------
# Create and send welcome emails to new customers
# Google Doc
# Gmail
# --------------------------------------------------------------------------------
# Attend training session on new software update
# Confluence
# Google Slides
# --------------------------------------------------------------------------------
# Preparing contract amendments for approval from senior management
# Confluence
# Google Doc
# --------------------------------------------------------------------------------
# Prepare and submit compliance reports to management and regulatory bodies
# Confluence
# Google Doc
# --------------------------------------------------------------------------------
# Schedule maintenance window for new software release
# Google Calendar
# Confluence
# --------------------------------------------------------------------------------
# Collaborating with internal teams to improve service processes
# Miro
# Confluence
# --------------------------------------------------------------------------------
# Reviewing supplier performance metrics
# Confluence
# Google Sheets
# --------------------------------------------------------------------------------
# Monitoring network uptime and connectivity
# Coda
# Confluence
# --------------------------------------------------------------------------------
# Reviewing payroll tax compliance status
# Confluence
# Google Sheets
# --------------------------------------------------------------------------------
# Developing a predictive model to forecast sales based on historical data
# Google Sheets
# GitHub
# --------------------------------------------------------------------------------
# Negotiate rates with vendors to optimize costs
# Jira
# Gmail
# --------------------------------------------------------------------------------
# Updating company's cloud provider agreements
# Confluence
# Google Doc
# --------------------------------------------------------------------------------
# Conduct internal controls assessment of accounting processes
# Jira
# Confluence
# --------------------------------------------------------------------------------
# Optimizing player lag in high-end gaming consoles
# Jira
# GitHub
# --------------------------------------------------------------------------------
# Negotiating partnerships with medical device manufacturers
# Slack
# Gmail
# --------------------------------------------------------------------------------
# Assist in the creation of exhibits and visual aids for presentations
# Miro
# Google Slides
# --------------------------------------------------------------------------------
# Creating a dashboard to track compensation metrics over time
# Confluence
# Google Sheets
# --------------------------------------------------------------------------------
# Implement two-factor authentication for all employee accounts
# Jira
# Confluence
# --------------------------------------------------------------------------------
# Developing a report on the environmental impact of materials usage in NGO operations
# Google Slides
# Google Doc
# --------------------------------------------------------------------------------
# Meet with vendors to discuss contract renewals
# Slack
# Gmail
# --------------------------------------------------------------------------------
# Research and implement new accounting software to improve efficiency
# Google Doc
# Confluence
# --------------------------------------------------------------------------------
# Testing and validating the accuracy of a sentiment analysis model
# Miro
# GitHub
# --------------------------------------------------------------------------------
# Negotiate payment terms with vendors on outstanding invoices
# Slack
# Gmail
# --------------------------------------------------------------------------------
# Developing a contingency plan for emergency situations
# Miro
# Confluence
# --------------------------------------------------------------------------------
# Creating a content calendar for the next 6 months of email newsletters
# Google Doc
# Google Sheets
# --------------------------------------------------------------------------------
# Collaborating with the Legal Department to review and update contracts
# Slack
# Google Doc
# --------------------------------------------------------------------------------
# Scheduling meetings with key stakeholders to discuss procurement options
# Google Calendar
# Gmail
# --------------------------------------------------------------------------------
# Collaborating with external partners to develop intellectual property
# GitHub
# Google Doc
# --------------------------------------------------------------------------------
# Develop a quarterly tax budget plan for the company
# Coda
# Google Sheets
# --------------------------------------------------------------------------------
# Building an AI-powered chatbot for customer support inquiries
# Confluence
# GitHub
# --------------------------------------------------------------------------------
# Researching emerging trends in sustainable energy solutions
# GitHub
# Confluence
# --------------------------------------------------------------------------------
# Conducting research on industry-specific contract laws
# Google Doc
# Confluence
# --------------------------------------------------------------------------------
# Developing a proof-of-concept prototype for a new virtual reality experience
# Confluence
# GitHub
# --------------------------------------------------------------------------------
# Develop and send out reminders about upcoming compliance deadlines
# Gmail
# Confluence
# --------------------------------------------------------------------------------
# Conduct cash flow forecasting for the next 6 months
# Google Slides
# Google Sheets
# --------------------------------------------------------------------------------
# Schedule meetings with key decision-makers at Fortune 500 companies
# Google Calendar
# Gmail
# --------------------------------------------------------------------------------
# Analyze and report on inventory levels and lead times
# Miro
# Google Sheets
# --------------------------------------------------------------------------------
# Creating and sending out RFPs (requests for proposals) to potential vendors
# Google Slides
# Google Doc
# --------------------------------------------------------------------------------
# Analyzing industry trends to identify opportunities for cost savings
# Google Doc
# Google Sheets
# --------------------------------------------------------------------------------
# Schedule follow-up meetings with existing customers
# Google Calendar
# Gmail
# --------------------------------------------------------------------------------
# Collaborate with cross-functional teams to develop strategic sourcing plan
# Google Slides
# Confluence
# --------------------------------------------------------------------------------
# Coordinate logistics for upcoming shipment
# Coda
# Google Sheets
# --------------------------------------------------------------------------------
# Respond to customer inquiries via phone and email
# Slack
# Confluence
# --------------------------------------------------------------------------------
# Developing a data pipeline to collect and process large amounts of financial transaction data
# Coda
# GitHub
# --------------------------------------------------------------------------------
# Conduct regular backups of critical databases to ensure business continuity
# Google Sheets
# Confluence
# --------------------------------------------------------------------------------
# Develop and implement a new lead generation strategy
# Miro
# Confluence
# --------------------------------------------------------------------------------
# Troubleshoot internet connectivity issues for residential customers
# Google Doc
# Confluence
# --------------------------------------------------------------------------------
# Reviewing financial reports for the first quarter
# Google Doc
# Google Sheets
# --------------------------------------------------------------------------------

# %%
# replace the annotations with the validated ones
annot_validated['final_tool'] = np.where(annot_validated['ok'] == 'Y', annot_validated['tool_to_search'], annot_validated['better'])
annot_validated.head()
# Out:
#    user_idx  task_idx                                               task  \
# 0       185         0  Reviewing shipment schedules for the next quarter
# 1       185         1  Conducting cycle count on raw materials inventory
# 2       185         2  Analyzing sales data to identify trends in mat...
# 3       185         3             Creating and updating vendor contracts
# 4       185         4  Verifying compliance with regulatory standards...
#
#   tool_to_search ok better     final_tool
# 0  Google Sheets  Y      -  Google Sheets
# 1  Google Sheets  Y      -  Google Sheets
# 2  Google Sheets  Y      -  Google Sheets
# 3    Google Docs  Y      -    Google Docs
# 4     Confluence  Y      -     Confluence

# %%
assert annot_validated['final_tool'].notna().all()
assert annot_validated['final_tool'].isin(['Coda', 'Confluence', 'Jira', 'Google Docs', 'Slack', 'Miro', 'Google Slides', 'Google Sheets', 'Gmail', 'GitHub']).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 assert annot_validated['final_tool'].notna().all()
# ----> 2 assert annot_validated['final_tool'].isin(['Coda', 'Confluence', 'Jira', 'Google Docs', 'Slack', 'Miro', 'Google Slides', 'Google Sheets', 'Gmail', 'GitHub']).all()
#
# AssertionError:

# %%
# fix some typos
annot_validated['final_tool'] = annot_validated['final_tool'].replace('Google Doc', 'Google Docs')
annot_validated['final_tool'] = annot_validated['final_tool'].apply(lambda x: ' '.join(word.capitalize() for word in x.split()))
annot_validated['final_tool'] = annot_validated['final_tool'].replace('Github', 'GitHub')

# %%
annot_validated[~annot_validated['final_tool'].isin(['Coda', 'Confluence', 'Jira', 'Google Docs', 'Slack', 'Miro', 'Google Slides', 'Google Sheets', 'Gmail', 'GitHub'])]
# Out:
#        user_idx  task_idx                                               task  \
# 13444      9938         4  Update the CRM system with new contact informa...
# 46225      5417         5  Analyzing candidate feedback to improve the in...
# 73172      4389         2              Schedule appointments with new client
# 73173      4389         3                    Update operations team calendar
# 73177      4389         7     Re-schedule meeting with conflicting attendees
# 73179      4389         9  Book conference room reservations for internal...
# 90915       385         5                Schedule meetings with stakeholders
# 91406      2290         6  Coordinate team meeting to discuss current pro...
#
#                                           tool_to_search ok better  \
# 13444  CRM System (not listed, use Confluence for gui...  Y      -
# 46225                                       Google Forms  Y      -
# 73172                                    Google Calendar  Y      -
# 73173                                    Google Calendar  Y      -
# 73177                                    Google Calendar  Y      -
# 73179                                    Google Calendar  Y      -
# 90915                                    Google Calendar  Y      -
# 91406                                    Google Calendar  Y      -
#
#                                               final_tool
# 13444  Crm System (not Listed, Use Confluence For Gui...
# 46225                                       Google Forms
# 73172                                    Google Calendar
# 73173                                    Google Calendar
# 73177                                    Google Calendar
# 73179                                    Google Calendar
# 90915                                    Google Calendar
# 91406                                    Google Calendar

# %%
# reannotate the miss-annotated ones
reannot = annot_validated[~annot_validated['final_tool'].isin(['Coda', 'Confluence', 'Jira', 'Google Docs', 'Slack', 'Miro', 'Google Slides', 'Google Sheets', 'Gmail', 'GitHub'])]

import json
from star_utils import query_llm_proxy, get_llm_proxy_api_token

# config ───────────────────────────────────
BACKEND   = "openai_direct_o3"  
TOKEN     = get_llm_proxy_api_token()
ALLOWED   = ["Coda","Confluence","Jira","Google Docs","Slack","Miro",
             "Google Slides","Google Sheets","Gmail","GitHub"]

schema = {
    "name": "tool_fix",
    "strict": True,
    "type":   "object",
    "properties": {
        "tool_validation": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {"tool_to_search": {"type": "string"}},
                "required": ["tool_to_search"],
                "additionalProperties": False
            },
            "minItems": 1,
            "maxItems": 1
        }
    },
    "required": ["tool_validation"],
    "additionalProperties": False
}


PROMPT_TMPL = """
You are validating **one** task–tool pair.

────────────────────────────────────────────────────────
TASK
{task}

ANNOTATED TOOL (invalid): {bad}

────────────────────────────────────────────────────────
ALLOWED TOOLS
  • Coda            → project docs, structured check-lists, trackers
  • Confluence      → wiki-style knowledge base, SOPs, policies
  • Jira            → task / ticket tracking, engineering back-log
  • Google Docs     → narrative docs, contracts, one-off write-ups
  • Slack           → real-time chat, quick Q&A, ad-hoc coordination
  • Miro            → brainstorming, white-boarding, visual planning
  • Google Slides   → presentations, slide decks
  • Google Sheets   → tabular data, metrics dashboards, trackers
  • Gmail           → external / formal email threads, 1-to-1 comms
  • GitHub          → code, version-controlled tech docs, CI logs
────────────────────────────────────────────────────────
DECISION RULES
1. **Pick exactly one tool from the allowed list** – nothing else.
2. Match the tool to the **primary work-mode** of the task:
   • Long-form policy / procedure → Confluence or Google Docs  
   • Ticket / bug / backlog item  → Jira  
   • Scheduling / coordination    → Slack or Gmail  
   • Metrics / tabular analysis    → Google Sheets  
   • Code / scripts / CI logs      → GitHub  
   • Brainstorm / mind-map         → Miro  
   • Slide deck prep               → Google Slides  
   • Multi-step check-lists        → Coda  
3. Only choose Confluence for wiki/knowledge-base work,
   not generic “find info” tasks.
4. If none of the mappings fit, pick the tool that minimizes
   search time given the task context.

────────────────────────────────────────────────────────
Return JSON only:
{{
  "tool_validation": [ {{ "tool_to_search": "<one allowed tool>" }} ]
}}
""".strip()


def ask_fix(task:str, bad:str)->str:
    prompt = PROMPT_TMPL.format(task=task, bad=bad, allowed=", ".join(ALLOWED))
    resp   = query_llm_proxy(prompt,
                             backend=BACKEND,
                             schema=schema,
                             sleep_time=0,
                             api_token=TOKEN)
    return json.loads(resp["chunk"]["text"])["tool_validation"][0]["tool_to_search"]

fixed_tools = []
for _, row in reannot.iterrows():
    try:
        new_tool = ask_fix(row["task"], row["tool_to_search"])
    except Exception as e:
        new_tool = "ERR"
        print(f"failed user_idx={row['user_idx']}, task_idx={row['task_idx']}  → {e}")
    fixed_tools.append(new_tool)

reannot = reannot.assign(fixed_tool=fixed_tools)
reannot
# Out:
#        user_idx  task_idx                                               task  \
# 13444      9938         4  Update the CRM system with new contact informa...
# 46225      5417         5  Analyzing candidate feedback to improve the in...
# 73172      4389         2              Schedule appointments with new client
# 73173      4389         3                    Update operations team calendar
# 73177      4389         7     Re-schedule meeting with conflicting attendees
# 73179      4389         9  Book conference room reservations for internal...
# 90915       385         5                Schedule meetings with stakeholders
# 91406      2290         6  Coordinate team meeting to discuss current pro...
#
#                                           tool_to_search ok better  \
# 13444  CRM System (not listed, use Confluence for gui...  Y      -
# 46225                                       Google Forms  Y      -
# 73172                                    Google Calendar  Y      -
# 73173                                    Google Calendar  Y      -
# 73177                                    Google Calendar  Y      -
# 73179                                    Google Calendar  Y      -
# 90915                                    Google Calendar  Y      -
# 91406                                    Google Calendar  Y      -
#
#                                               final_tool     fixed_tool
# 13444  Crm System (not Listed, Use Confluence For Gui...           Jira
# 46225                                       Google Forms  Google Sheets
# 73172                                    Google Calendar          Gmail
# 73173                                    Google Calendar          Slack
# 73177                                    Google Calendar          Slack
# 73179                                    Google Calendar          Slack
# 90915                                    Google Calendar          Slack
# 91406                                    Google Calendar          Slack

# %%
# merge back the fixed tools
annot_validated['final_tool'].update(reannot['fixed_tool'])
assert annot_validated['final_tool'].isin(['Coda', 'Confluence', 'Jira', 'Google Docs', 'Slack', 'Miro', 'Google Slides', 'Google Sheets', 'Gmail', 'GitHub']).all()

# %%
# merge with the long queries dataset
data = []
with open("long_queries.jsonl", 'r', encoding='utf-8', errors='replace') as f:
    for line in f:
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError as e:
            print(f"Skipping invalid line: {e}")
            
df_queries = pd.DataFrame(data)

group_cols = [
    'name', 'employee_tenure', 'department', 'job_title',
    'company_size', 'company_sector', 'tasks'
]
df_queries['tasks'] = df_queries['tasks'].apply(tuple)
# Assign a unique group ID starting from 0
df_queries['user_idx'] = df_queries.groupby(group_cols).ngroup()
df_queries['tasks'] = df_queries['tasks'].apply(list)

keys = ['user_idx', 'task_idx']
df_queries = df_queries.merge(
    annot_validated[['user_idx', 'task_idx', 'final_tool']],
    on=keys,
    how='left'
)
df_queries.head()
# Out:
# Skipping invalid line: Extra data: line 1 column 1618 (char 1617)
#         name employee_tenure                  department  \
# 0  Alexander     experienced  Customer Support / Service
# 1  Alexander     experienced  Customer Support / Service
# 2  Alexander     experienced  Customer Support / Service
# 3  Alexander     experienced  Customer Support / Service
# 4  Alexander     experienced  Customer Support / Service
#
#                job_title company_size     company_sector  \
# 0  Resolution Specialist    mid-sized  Legal & Law Firms
# 1  Resolution Specialist    mid-sized  Legal & Law Firms
# 2  Resolution Specialist    mid-sized  Legal & Law Firms
# 3  Resolution Specialist    mid-sized  Legal & Law Firms
# 4  Resolution Specialist    mid-sized  Legal & Law Firms
#
#                                                tasks  \
# 0  [Respond to 3 customer complaints via email, I...
# 1  [Respond to 3 customer complaints via email, I...
# 2  [Respond to 3 customer complaints via email, I...
# 3  [Respond to 3 customer complaints via email, I...
# 4  [Respond to 3 customer complaints via email, I...
#
#                                         long_queries  line_idx  task_idx task  \
# 0  [resolution support customer service legal iss...         0         0  NaN
# 1  [client account payment issues legal billing d...         0         1  NaN
# 2  [escalate high priority cases to senior manage...         0         2  NaN
# 3  [Drafting a document update response for clien...         0         3  NaN
# 4  [Change of schedule coordination, Scheduling c...         0         4  NaN
#
#    user_idx   final_tool
# 0        17        Gmail
# 1        17   Confluence
# 2        17        Slack
# 3        17  Google Docs
# 4        17        Slack

# %%
len(df_queries)
# Out:
# 104548

# %%
with open("long_queries_with_tools.json", "w", encoding="utf-8", errors="replace") as f:
    for record in df_queries.to_dict(orient="records"):
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

# %%
df_queries.explode('long_queries')
# Out:
#              name employee_tenure                  department  \
# 0       Alexander     experienced  Customer Support / Service
# 0       Alexander     experienced  Customer Support / Service
# 0       Alexander     experienced  Customer Support / Service
# 0       Alexander     experienced  Customer Support / Service
# 0       Alexander     experienced  Customer Support / Service
# ...           ...             ...                         ...
# 104547       Liam     experienced                  Operations
# 104547       Liam     experienced                  Operations
# 104547       Liam     experienced                  Operations
# 104547       Liam     experienced                  Operations
# 104547       Liam     experienced                  Operations
#
#                                 job_title company_size  \
# 0                   Resolution Specialist    mid-sized
# 0                   Resolution Specialist    mid-sized
# 0                   Resolution Specialist    mid-sized
# 0                   Resolution Specialist    mid-sized
# 0                   Resolution Specialist    mid-sized
# ...                                   ...          ...
# 104547  Production Scheduling Coordinator        large
# 104547  Production Scheduling Coordinator        large
# 104547  Production Scheduling Coordinator        large
# 104547  Production Scheduling Coordinator        large
# 104547  Production Scheduling Coordinator        large
#
#                     company_sector  \
# 0                Legal & Law Firms
# 0                Legal & Law Firms
# 0                Legal & Law Firms
# 0                Legal & Law Firms
# 0                Legal & Law Firms
# ...                            ...
# 104547  Government & Public Sector
# 104547  Government & Public Sector
# 104547  Government & Public Sector
# 104547  Government & Public Sector
# 104547  Government & Public Sector
#
#                                                     tasks  \
# 0       [Respond to 3 customer complaints via email, I...
# 0       [Respond to 3 customer complaints via email, I...
# 0       [Respond to 3 customer complaints via email, I...
# 0       [Respond to 3 customer complaints via email, I...
# 0       [Respond to 3 customer complaints via email, I...
# ...                                                   ...
# 104547  [Review and update production schedules for up...
# 104547  [Review and update production schedules for up...
# 104547  [Review and update production schedules for up...
# 104547  [Review and update production schedules for up...
# 104547  [Review and update production schedules for up...
#
#                                              long_queries  line_idx  task_idx  \
# 0       resolution support customer service legal issu...         0         0
# 0       customer complaints email template resolution ...         0         0
# 0       complaints management service customer support...         0         0
# 0       legal firm customer service email responses co...         0         0
# 0       mid-sized law firms complaint handling procedu...         0         0
# ...                                                   ...       ...       ...
# 104547    public sector employee communication guidelines     10455         9
# 104547     government team updates coordination processes     10455         9
# 104547      scheduling coordinator changes email drafting     10455         9
# 104547        large company operations news dissemination     10455         9
# 104547      public sector employee management information     10455         9
#
#                                                      task  user_idx final_tool
# 0                                                     NaN        17      Gmail
# 0                                                     NaN        17      Gmail
# 0                                                     NaN        17      Gmail
# 0                                                     NaN        17      Gmail
# 0                                                     NaN        17      Gmail
# ...                                                   ...       ...        ...
# 104547  Communicate with teams and personnel regarding...      6408      Slack
# 104547  Communicate with teams and personnel regarding...      6408      Slack
# 104547  Communicate with teams and personnel regarding...      6408      Slack
# 104547  Communicate with teams and personnel regarding...      6408      Slack
# 104547  Communicate with teams and personnel regarding...      6408      Slack
#
# [1045480 rows x 13 columns]
